# %% [markdown]
# <a href="https://colab.research.google.com/github/Teasotea/textSummarization/blob/main/TextSummarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load Data

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
conversation_df = pd.read_csv('https://raw.githubusercontent.com/Teasotea/textSummarization/main/data/session.csv', delimiter = "\t", header=None)
conversation_df = conversation_df.style.set_properties(**{'text-align': 'left'})
conversation_df
# Out:
# <style type="text/css">
# #T_046a7_row0_col0, #T_046a7_row1_col0, #T_046a7_row2_col0, #T_046a7_row3_col0, #T_046a7_row4_col0, #T_046a7_row5_col0, #T_046a7_row6_col0, #T_046a7_row7_col0, #T_046a7_row8_col0, #T_046a7_row9_col0, #T_046a7_row10_col0, #T_046a7_row11_col0, #T_046a7_row12_col0, #T_046a7_row13_col0, #T_046a7_row14_col0, #T_046a7_row15_col0, #T_046a7_row16_col0, #T_046a7_row17_col0, #T_046a7_row18_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_046a7_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_046a7_level0_row0" class="row_heading level0 row0" >0</th>
# ...
